# %%
# !git clone -b Sinkhorn-GAN https://github.com/kallel-mahdi/SinGAN2
# %cd SinGAN2 
# !pip install -q celery
# Out:
# Cloning into 'SinGAN2'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 2775 (delta 56), reused 63 (delta 28), pack-reused 2683
# Receiving objects: 100% (2775/2775), 464.25 MiB | 26.68 MiB/s, done.
# Resolving deltas: 100% (650/650), done.
# /content/SinGAN2
#      |████████████████████████████████| 399kB 13.4MB/s
#      |████████████████████████████████| 184kB 22.3MB/s
#      |████████████████████████████████| 92kB 10.3MB/s
#      |████████████████████████████████| 51kB 7.1MB/s
# ...

# %%
## if you dont want sinkhorn just take off the flag
# !python main_train.py --img ferrari_488.png --N 7 --steps_per_scale 2500 --run_name ferrari_sink --grad_penalty True --sink True
# Out:
# Gradient penalty = True
# Using sinkhorn loss =  True
# 2021-01-09 00:52:19.300134: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Grad penalty= True Sinkhorn = True
# [(18, 36), (24, 48), (32, 65), (43, 87), (57, 116), (76, 154), (102, 206), (136, 275)]
# After operation img size is torch.Size([1, 3, 136, 275])
# Input shape =  torch.Size([1, 3, 136, 275])
# For scale  0 kernel size is 3 stride is 1
# [1.0]
# [7: 100|2500] - {'batch_size': 648, 'embed_size': 32, 'sink_distance': 31.647581100463867, 'rec_g_loss': 0.05516873836517334}
# [7: 200|2500] - {'batch_size': 648, 'embed_size': 32, 'sink_distance': 42.52836227416992, 'rec_g_loss': 0.025322270393371583}
# [7: 300|2500] - {'batch_size': 648, 'embed_size': 32, 'sink_distance': 43.94155502319336, 'rec_g_loss': 0.021958925724029542}
# [7: 400|2500] - {'batch_size': 648, 'embed_size': 32, 'sink_distance': 47.356422424316406, 'rec_g_loss': 0.02040747880935669}
# ...

# %%
# !python train_double.py --img ferrari_488.png --N 8 --steps_per_scale 2000 --run_name ferrari_double --grad_penalty True

# %%
# !python paint2image.py --run_name ferrari_488_png --paint car2_blue.png
# Out:
# 2021-01-08 11:13:23.568178: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Grad penalty= True Sinkhorn = False

# %%
# !python SIFID/sifid_score.py --path2real ./imgs_real --path2fake ./imgs_generated
# Out:
# 100% 1/1 [00:00<00:00, 46.08it/s]
# 100% 1/1 [00:00<00:00, 44.95it/s]
# SIFID:  1.4185957

# %%
#### REVERT TO THIS COMMIT IN CASE THINGS GO SOUTH (EVERYTHING MUST BE IN PNG!!!!!)
# !git checkout ee2e8ca54a8bbbbbc712
# Out:
# Note: checking out 'ee2e8ca54a8bbbbbc712'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at ee2e8ca Now (re)debugging sink

# %%
# !zip -r /content/ferrari.zip /content/SinGAN2/logs
# Out:
#   adding: content/SinGAN2/logs/ (stored 0%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/ (stored 0%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_2_rec_g_loss/ (stored 0%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_2_rec_g_loss/events.out.tfevents.1610104007.8c2d1535e668.101.28 (deflated 67%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_4_adv_d_real_loss/ (stored 0%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_4_adv_d_real_loss/events.out.tfevents.1610103856.8c2d1535e668.101.18 (deflated 67%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_3_adv_d_real_loss/ (stored 0%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_3_adv_d_real_loss/events.out.tfevents.1610103929.8c2d1535e668.101.22 (deflated 67%)
#   adding: content/SinGAN2/logs/singan_ferrari_488_png/training_0_adv_d_real_loss/ (stored 0%)
# ...
